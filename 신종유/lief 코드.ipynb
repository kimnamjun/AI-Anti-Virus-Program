# %%
import lief

# %%
binary = lief.parse("C:\Program Files\Internet Explorer\iexplore.exe")
print(binary)
# Out:
# Dos Header
# ...
# Magic:                        5a4d
# Used Bytes In The LastPage:   90
# File Size In Pages:           3
# Number Of Relocation:         0
# Header Size In Paragraphs:    4
# Minimum Extra Paragraphs:     0
# Maximum Extra Paragraphs:     ffff
# Initial Relative SS:          0
# Initial SP:                   b8
# Checksum:                     0
# Initial IP:                   0
# Initial Relative CS:          0
# Address Of Relocation Table:  40
# Overlay Number:               0
# OEM id:                       0
# OEM info:                     0
# Address Of New Exe Header:    f0
#
# Rich Header
# ...
# Key: 8cf6f001
#   - ID: 0x1020 Build ID: 0x6b14 Count: 1
#   - ID: 0xff00 Build ID: 0x6b14 Count: 1
#   - ID: 0x10d0 Build ID: 0x6b14 Count: 11
#   - ID: 0x1000 Build ID: 0x0000 Count: 142
#   - ID: 0x1010 Build ID: 0x6b14 Count: 13
#   - ID: 0x1050 Build ID: 0x6b14 Count: 5
#   - ID: 0x1040 Build ID: 0x6b14 Count: 20
#   - ID: 0x1030 Build ID: 0x6b14 Count: 3
# ...

# %%
type(binary)
# Out:
# lief.PE.Binary

# %%
binary = str(binary)

# %%
print(binary)
# Out:
# Dos Header
# ...
# Magic:                        5a4d
# Used Bytes In The LastPage:   90
# File Size In Pages:           3
# Number Of Relocation:         0
# Header Size In Paragraphs:    4
# Minimum Extra Paragraphs:     0
# Maximum Extra Paragraphs:     ffff
# Initial Relative SS:          0
# Initial SP:                   b8
# Checksum:                     0
# Initial IP:                   0
# Initial Relative CS:          0
# Address Of Relocation Table:  40
# Overlay Number:               0
# OEM id:                       0
# OEM info:                     0
# Address Of New Exe Header:    f0
#
# Rich Header
# ...
# Key: 8cf6f001
#   - ID: 0x1020 Build ID: 0x6b14 Count: 1
#   - ID: 0xff00 Build ID: 0x6b14 Count: 1
#   - ID: 0x10d0 Build ID: 0x6b14 Count: 11
#   - ID: 0x1000 Build ID: 0x0000 Count: 142
#   - ID: 0x1010 Build ID: 0x6b14 Count: 13
#   - ID: 0x1050 Build ID: 0x6b14 Count: 5
#   - ID: 0x1040 Build ID: 0x6b14 Count: 20
#   - ID: 0x1030 Build ID: 0x6b14 Count: 3
# ...

# %%
type(binary)
# Out:
# str

# %%
f = open('test01.txt', 'a', -1, 'utf-8') # 파일 열기
temp = binary
print(temp, file=f) # 파일 저장하기
f.close()
