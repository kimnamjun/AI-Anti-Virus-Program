# %%
# !pip install jsonlines

# %%
import jsonlines

# %%
with jsonlines.open("/content/train_features_0.jsonl") as f:
  for line in f.iter():
    print(line["section"])
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ...
